# %%
import pandas as pd

# %%
df=pd.read_csv('/home/pranita/PRANITA/M.Tech(CDAC)/ML/files/Gender_Height_Weight_Index.csv')

# %%
df.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
male_data=df[df['Gender']=='Male']
male_data.shape
# Out:
# (245, 4)

# %%
female_data=df[df['Gender']=='Female']

# %%
df.keys()
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
df_val=df.drop('Gender',1)

# %%
df_val
# Out:
#      Height  Weight  Index
# 0       174      96      4
# 1       189      87      2
# 2       185     110      4
# 3       195     104      3
# 4       149      61      3
# 5       189     104      3
# 6       147      92      5
# 7       154     111      5
# 8       174      90      3
# 9       169     103      4
# 10      195      81      2
# 11      159      80      4
# 12      192     101      3
# 13      155      51      2
# 14      191      79      2
# 15      153     107      5
# 16      157     110      5
# 17      140     129      5
# 18      144     145      5
# 19      172     139      5
# 20      157     110      5
# 21      153     149      5
# 22      169      97      4
# 23      185     139      5
# 24      172      67      2
# 25      151      64      3
# 26      190      95      3
# 27      187      62      1
# 28      163     159      5
# 29      179     152      5
# ..      ...     ...    ...
# 470     147     142      5
# 471     154     112      5
# ...

# %%
df_val=df_val[['Height','Weight']]
df_val
# Out:
#      Height  Weight
# 0       174      96
# 1       189      87
# 2       185     110
# 3       195     104
# 4       149      61
# 5       189     104
# 6       147      92
# 7       154     111
# 8       174      90
# 9       169     103
# 10      195      81
# 11      159      80
# 12      192     101
# 13      155      51
# 14      191      79
# 15      153     107
# 16      157     110
# 17      140     129
# 18      144     145
# 19      172     139
# 20      157     110
# 21      153     149
# 22      169      97
# 23      185     139
# 24      172      67
# 25      151      64
# 26      190      95
# 27      187      62
# 28      163     159
# 29      179     152
# ..      ...     ...
# 470     147     142
# 471     154     112
# 472     178      65
# 473     195     153
# 474     167      79
# 475     183     131
# 476     164     142
# 477     167      64
# 478     151      55
# 479     147     107
# 480     155     115
# 481     172     108
# 482     142      86
# ...

# %%
len(df_val)
# Out:
# 500

# %%
#from sklearn import cross_validation
#from sklearn import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
x=df_val['Height']
y=df_val['Weight']
x_val=np.array(x)
y_val=np.array(y)
x_val=x_val.reshape(-1,1)
y_val=y_val.reshape(-1,1)

# %%
xTrain,xTest,yTrain,yTest=train_test_split(x_val,y_val,test_size=0.1)

# %%
# Machine Learning Algorithm
lr=LinearRegression()
lr.fit(xTrain,yTrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
accuracy=lr.score(xTest,yTest)
accuracy
# Out:
# -0.021816420702666983
